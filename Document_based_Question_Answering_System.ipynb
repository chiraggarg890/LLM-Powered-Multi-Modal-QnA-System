# %% [markdown]
# #Installing required packages:

# %%
# !pip install --upgrade langchain openai -q
# !pip install unstructured -q
# !pip install unstructured[local-inference] -q
# !pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# !apt-get install poppler-utils
# !pip install faiss-cpu
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# whisper
#! pip install git+https://github.com/huggingface/transformers -q
# for changing audio extension
! pip install git+https://github.com/openai/whisper.git -q
# !pip install pydub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 42.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 62.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 69.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('gdrive')

# %%
# import required modules
import os
from os import path
import shutil
from pydub import AudioSegment
import whisper

model = whisper.load_model("medium")

# %%
os.chdir('/content/gdrive/MyDrive/Document_qna')

# %%
# !pip install tesseract
# !pip install tesseract-ocr
# !pip install libxml2
# !pip install libxslt
# !pip install libmagic

# %% [markdown]
# # Supported Audio formats
#
# m4a
#
# mp3
#
# webm
#
# mp4
#
# mpga
#
# wav
#
# mpeg

# %%
import os

path =os.path.join(os.getcwd(),'Document_qna_data')
ls= []
for root, dirs, files in os.walk(path):
	for file in files:
		if(file.endswith(".m4a") or file.endswith(".mp3") or file.endswith(".webm") or file.endswith(".mp4") or file.endswith(".mpga") or file.endswith(".wav") or file.endswith(".mpeg")):
		  ls.append(os.path.join(root,file))

# %%
print(ls[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-a1139d225399> in <cell line: 1>()
# ----> 1 print(ls[0])
#
# IndexError: list index out of range

# %%
length=len(ls)

# %%
if(length!=0):
  output_path=os.path.join(os.getcwd(),'Audio_to_Text')
  for inpath in ls:
    name_of_file=inpath.split('/')[-1]
    outpath=os.path.join(output_path,name_of_file)
    shutil.move(inpath,outpath )

# %%
if(length!=0):
  all_output_paths=[]
  input_path=os.path.join(os.getcwd(),'Audio_to_Text')
  output_directory_path=os.path.join(os.getcwd(),'All_Formatted_Input_Audios')
  for filename in os.listdir('Audio_to_Text'):

    # assign files
    input_file = os.path.join(input_path,filename)
    #print(type(input_file))
    format_of_input_file=filename.split(".")[-1]
    #print(type(format_of_input_file))
    if(format_of_input_file=='m4a'):
      output_file_name=filename.split(".")[0]+".wav"
      output_file = os.path.join(output_directory_path,output_file_name)
      all_output_paths.append(output_file)
      print(output_file_name)

      # convert mp3 file to wav file
      sound = AudioSegment.from_file(input_file, format=format_of_input_file)
      sound.export(output_file, format='wav')
      os.remove(input_file)
    else:
      output_file = os.path.join(output_directory_path,filename)
      all_output_paths.append(output_file)
      shutil.copy(input_file, output_file)
      os.remove(input_file)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-9-0e91f3f6a952> in <cell line: 4>()
#      21     output_file = os.path.join(output_directory_path,filename)
#      22     all_output_paths.append(output_file)
# ---> 23     shutil.copy(input_file, output_file)
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     252         os.symlink(os.readlink(src), dst)
#     253     else:
# --> 254         with open(src, 'rb') as fsrc:
#     255             try:
#     256                 with open(dst, 'wb') as fdst:
#
# ...

# %%
# !nvidia-smi
# Out:
# Sun Aug  6 06:37:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#from transformers import pipeline

# %%
#whisper = pipeline('automatic-speech-recognition', model = 'openai/whisper-medium',device=0)

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Document_qna

# %%
def translate(audio):

    options = dict(beam_size=5, best_of=5)
    translate_options = dict(task="translate",fp16=False, **options)
    result = model.transcribe(audio,**translate_options)
    return result

# %%
text_audio_file_path=os.path.join(os.getcwd(),'Document_qna_data/Audio_to_texxt')
for audio_file_path in all_output_paths:
  opath=audio_file_path.split('/')[-1].split('.')[0]+".txt"
  result = translate(audio_file_path)
  str_text=str(result["text"])
  final_path=os.path.join(text_audio_file_path,opath)
  os.remove(audio_file_path)
  with open(final_path,'w') as f:
    f.write(str_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0378fe22e3f6> in <cell line: 2>()
#       2 for audio_file_path in all_output_paths:
#       3   opath=audio_file_path.split('/')[-1].split('.')[0]+".txt"
# ----> 4   text = whisper(audio_file_path)
#       5   str_text=str(text)
#       6   final_path=os.path.join(text_audio_file_path,opath)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/automatic_speech_recognition.py in __call__(self, inputs, **kwargs)
#     272                         `"".join(chunk["text"] for chunk in output["chunks"])`.
#     273         """
# --> 274         return super().__call__(inputs, **kwargs)
#     275
#     276     def _sanitize_parameters(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
# ...

# %%
# txt=whisper('/content/gdrive/MyDrive/Document_qna/All_Formatted_Input_Audios/videoplayback.mp4')
# hhh=str(txt)
# finn_path=os.path.join('/content/gdrive/MyDrive/Document_qna/Document_qna_data/Audio_to_texxt','videoplayback.txt')
# with open(finn_path,'w') as f:
#   f.write(hhh)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1453: UserWarning: Using the model-agnostic default `max_length` (=448) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
# txt=whisper('/content/gdrive/MyDrive/Document_qna/All_Formatted_Input_Audios/Ukraine.mp3')
# hhh=str(txt)
# finn_path=os.path.join('/content/gdrive/MyDrive/Document_qna/Document_qna_data/Audio_to_texxt','Ukraine.txt')
# with open(finn_path,'w') as f:
#   f.write(hhh)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1453: UserWarning: Using the model-agnostic default `max_length` (=448) to control the generation length.  recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
# text

# %% [markdown]
# #Importing necessary libraries:

# %%
import os
import openai
import pytesseract
import getpass
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
#from langchain.vectorstores import Pinecone
from langchain.vectorstores import FAISS
from langchain.llms import OpenAI
from langchain.chains.question_answering import load_qa_chain

# %%
pytesseract.pytesseract.tesseract_cmd = (
    r'/usr/bin/tesseract'
)

# %% [markdown]
# #Loading documents

# %%
# drive.mount("gdrive", force_remount=True)
# Out:
# Mounted at gdrive

# %%
#os.chdir('/gdrive/MyDrive')
directory = '/content/gdrive/MyDrive/Document_qna/Document_qna_data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 26

# %% [markdown]
# #Splitting documents

# %%
def split_docs(documents, chunk_size=1000, chunk_overlap=50):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 147

# %% [markdown]
# #Embedding documents with OpenAI

# %%
# !pip install tiktoken -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.8 MB/s eta 0:00:00

# %%
OPEN_API_KEY="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"

# %%
embeddings = OpenAIEmbeddings(openai_api_key=OPEN_API_KEY,model_name="ada")

query_result = embeddings.embed_query("Hello world")
len(query_result)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/embeddings/openai.py:214: UserWarning: WARNING! model_name is not default parameter.
#                     model_name was transferred to model_kwargs.
#                     Please confirm that model_name is what you intended.
#   warnings.warn(
# 1536

# %% [markdown]
# #Vector search with FAISS

# %%
# Load the document, split it into chunks, embed each chunk and load it into the vector store.
db = FAISS.from_documents(docs, embeddings)

# %%
def get_similiar_docs(query):
  embedding_vector = embeddings.embed_query(query)
  docs = db.similarity_search_by_vector(embedding_vector)
  return docs

# %%
query =" Explain in detail about Monte Carlo search tree?"
len(get_similiar_docs(query))
# Out:
# 4

# %% [markdown]
# #Question answering using LangChain and OpenAI LLM

# %%
# model_name = "text-davinci-003"
model_name = "gpt-3.5-turbo"
#model_name = "gpt-4"
llm = OpenAI(openai_api_key=OPEN_API_KEY,model_name=model_name)

chain = load_qa_chain(llm, chain_type="stuff")

def get_answer(query):
  similar_docs = get_similiar_docs(query)
  answer = chain.run(input_documents=similar_docs, question=query)
  return answer
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:201: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/llms/openai.py:786: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(

# %% [markdown]
# #Example queries and answers

# %%
query = "Where does Shetty lives?"
answer = get_answer(query)
print(answer)

# query = "How have relations between India and the US improved?"
# answer = get_answer(query)
# print(answer)
# Out:
# Nagpur
